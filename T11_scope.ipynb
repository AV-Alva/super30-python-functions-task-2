# %%
message = "I am a global variable"


def show_scope():
    """Demonstrate local and global variable scope."""
    local_message = "I am a local variable"

    print(message)
    print(local_message)


show_scope()

print("Global Message:", message)
#print("Local Message:", local_message)  # This will raise an error because local_message is not accessible here
# Out:
# I am a global variable
# I am a local variable
# Global Message: I am a global variable
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      11
#      12 show_scope()
#      13
#      14 print("Global Message:", message)
# ---> 15 print("Local Message:", local_message)  # This will raise an error because local_message is not accessible here
#
# NameError: name 'local_message' is not defined
